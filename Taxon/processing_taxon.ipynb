# %%
import numpy as np
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
from apyori import apriori
from mlxtend.preprocessing import TransactionEncoder
from tqdm import tqdm

# %%
queryString = "SELECT * WHERE { ?s ?p ?o. }"
sparql = SPARQLWrapper("http://localhost:3030/taxon/sparql")
sparql.setQuery(queryString)

try :
   ret = sparql.query()
   # ret is a stream with the results in XML, see <http://www.w3.org/TR/rdf-sparql-XMLres/>
except :
   pass

# %%
sparql.setQuery("""
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT ?s (COUNT(?prop) AS ?total) {
  
  SELECT DISTINCT ?s ?prop
    WHERE {
    # ?s wdt:P31 wd:Q16521 .
    # ?s ?prop ?value .
    }

} GROUP BY ?s
ORDER BY DESC(?total) 
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'vars': ['s', 'total']},
#  'results': {'bindings': [{'s': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q140'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '27'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q152'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '22'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q14443'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '18'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q19075'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '16'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q19078'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '16'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q19070'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '15'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q5176'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '15'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q14272'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '14'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q5174'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '14'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q5182'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '14'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10630'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '13'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10639'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '13'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10642'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '13'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10631'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10635'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10637'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '11'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q10669'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '9'}},
#    {'s': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q14532'},
#     'total': {'type': 'literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'}}]}}

# %%
res = []
for results in results["results"]["bindings"]:
    print('%s: %s' % (results["s"]["value"], results["total"]["value"]))
    entity = str(results["s"]["value"]).split('/')
    res.append(entity[-1])
print('---------------------------')
# Out:
# http://www.wikidata.org/entity/Q140: 27
# http://www.wikidata.org/entity/Q152: 22
# http://www.wikidata.org/entity/Q14443: 18
# http://www.wikidata.org/entity/Q19075: 16
# http://www.wikidata.org/entity/Q19078: 16
# http://www.wikidata.org/entity/Q19070: 15
# http://www.wikidata.org/entity/Q5176: 15
# http://www.wikidata.org/entity/Q14272: 14
# http://www.wikidata.org/entity/Q5174: 14
# http://www.wikidata.org/entity/Q5182: 14
# http://www.wikidata.org/entity/Q10630: 13
# http://www.wikidata.org/entity/Q10639: 13
# http://www.wikidata.org/entity/Q10642: 13
# http://www.wikidata.org/entity/Q10631: 12
# http://www.wikidata.org/entity/Q10635: 12
# http://www.wikidata.org/entity/Q10637: 11
# http://www.wikidata.org/entity/Q10669: 9
# http://www.wikidata.org/entity/Q14532: 8
# ---------------------------

# %%
db = []

for i in range(len(res)):
    query_string = """
    PREFIX wd: <http://www.wikidata.org/entity/>
    SELECT DISTINCT ?s ?prop {
    VALUES ?s {wd:""" + res[i] + """}
    # ?s ?prop ?value .
    }
    """

    sparql.setQuery(query_string)
    sparql.setReturnFormat(JSON)
    results_entity = sparql.query().convert()
    propLabel = []
    for results in results_entity["results"]["bindings"]:
#         print('%s: %s' % (results["country"]["value"], results["propLabel"]["value"]))
        propLabel.append(results["prop"]["value"])
#     print('---------------------------')
    db.append(propLabel)

# %%
te = TransactionEncoder()
te_ary = te.fit(db).transform(db)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     http://www.wikidata.org/prop/P105  http://www.wikidata.org/prop/P1343  \
# 0                                True                               False
# 1                                True                               False
# 2                                True                               False
# 3                                True                               False
# 4                                True                               False
# 5                                True                               False
# 6                                True                               False
# 7                                True                               False
# 8                                True                               False
# 9                                True                                True
# 10                               True                               False
# 11                               True                               False
# 12                               True                               False
# 13                               True                               False
# 14                               True                               False
# 15                               True                               False
# 16                               True                               False
# 17                               True                               False
#
#     http://www.wikidata.org/prop/P141  http://www.wikidata.org/prop/P1421  \
# 0                                True                               False
# 1                               False                               False
# 2                                True                               False
# 3                                True                               False
# 4                               False                               False
# 5                               False                                True
# 6                               False                               False
# 7                               False                               False
# 8                               False                               False
# 9                               False                               False
# 10                              False                               False
# 11                              False                               False
# 12                              False                               False
# 13                              False                               False
# 14                              False                               False
# 15                              False                               False
# 16                              False                               False
# 17                              False                               False
#
#     http://www.wikidata.org/prop/P1552  http://www.wikidata.org/prop/P171  \
# 0                                False                               True
# 1                                False                               True
# 2                                False                               True
# 3                                False                               True
# 4                                False                               True
# 5                                False                               True
# 6                                 True                               True
# 7                                False                               True
# 8                                False                               True
# 9                                False                               True
# 10                               False                               True
# 11                               False                               True
# 12                               False                               True
# 13                               False                               True
# 14                               False                               True
# 15                               False                               True
# 16                               False                               True
# 17                               False                               True
#
#     http://www.wikidata.org/prop/P18  http://www.wikidata.org/prop/P181  \
# 0                               True                               True
# 1                               True                              False
# 2                               True                              False
# 3                               True                              False
# 4                               True                              False
# 5                               True                              False
# 6                               True                              False
# 7                               True                              False
# 8                               True                              False
# 9                               True                              False
# 10                              True                               True
# 11                              True                               True
# 12                              True                               True
# 13                              True                               True
# 14                              True                               True
# 15                             False                               True
# 16                              True                               True
# 17                              True                              False
#
#     http://www.wikidata.org/prop/P1843  http://www.wikidata.org/prop/P1889  \
# 0                                 True                               False
# 1                                False                               False
# 2                                 True                               False
# 3                                 True                               False
# 4                                False                                True
# 5                                 True                               False
# 6                                 True                               False
# 7                                 True                               False
# 8                                False                               False
# 9                                False                               False
# 10                                True                               False
# 11                                True                               False
# 12                                True                               False
# 13                               False                               False
# 14                               False                               False
# 15                               False                               False
# 16                               False                               False
# 17                               False                               False
#
#     ...  http://www.wikidata.org/prop/direct/P2579  \
# 0   ...                                      False
# 1   ...                                       True
# 2   ...                                      False
# 3   ...                                      False
# 4   ...                                      False
# 5   ...                                      False
# 6   ...                                      False
# 7   ...                                      False
# 8   ...                                      False
# 9   ...                                      False
# 10  ...                                      False
# 11  ...                                      False
# 12  ...                                      False
# 13  ...                                      False
# 14  ...                                      False
# 15  ...                                      False
# 16  ...                                      False
# 17  ...                                      False
#
#     http://www.wikidata.org/prop/direct/P279  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# 7                                      False
# 8                                      False
# 9                                      False
# 10                                     False
# 11                                     False
# 12                                     False
# 13                                     False
# 14                                     False
# 15                                     False
# 16                                     False
# 17                                     False
#
#     http://www.wikidata.org/prop/direct/P2974  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                        True
# 5                                       False
# 6                                       False
# 7                                       False
# 8                                       False
# 9                                       False
# 10                                      False
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                      False
# 15                                      False
# 16                                      False
# 17                                      False
#
#     http://www.wikidata.org/prop/direct/P31  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
# 5                                      True
# 6                                      True
# 7                                      True
# 8                                      True
# 9                                      True
# 10                                     True
# 11                                     True
# 12                                     True
# 13                                     True
# 14                                     True
# 15                                     True
# 16                                     True
# 17                                     True
#
#     http://www.wikidata.org/prop/direct/P3512  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# 6                                       False
# 7                                       False
# 8                                       False
# 9                                       False
# 10                                      False
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                      False
# 15                                      False
# 16                                      False
# 17                                      False
#
#     http://www.wikidata.org/prop/direct/P361  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                       True
# 5                                      False
# 6                                      False
# 7                                      False
# 8                                      False
# 9                                      False
# 10                                     False
# 11                                     False
# 12                                     False
# 13                                     False
# 14                                     False
# 15                                     False
# 16                                     False
# 17                                     False
#
#     http://www.wikidata.org/prop/direct/P427  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# 5                                       True
# 6                                      False
# 7                                       True
# 8                                      False
# 9                                      False
# 10                                     False
# 11                                     False
# 12                                     False
# 13                                     False
# 14                                     False
# 15                                     False
# 16                                     False
# 17                                     False
#
#     http://www.wikidata.org/prop/direct/P5008  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# 6                                       False
# 7                                       False
# 8                                       False
# 9                                       False
# 10                                      False
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                      False
# 15                                      False
# 16                                      False
# 17                                      False
#
#     http://www.wikidata.org/prop/direct/P5125  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# 6                                       False
# 7                                       False
# 8                                       False
# 9                                       False
# 10                                      False
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                      False
# 15                                      False
# 16                                      False
# 17                                      False
#
#     http://www.wikidata.org/prop/direct/P910
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
# 5                                       True
# 6                                       True
# 7                                       True
# 8                                       True
# 9                                       True
# 10                                      True
# 11                                      True
# 12                                      True
# 13                                      True
# 14                                      True
# 15                                      True
# 16                                     False
# 17                                     False
#
# [18 rows x 53 columns]

# %%
wikidata = SPARQLWrapper("https://query.wikidata.org/sparql")

propList = df.columns.tolist()
for i in range(len(propList)):
    propList[i]=propList[i].split('/')[-1]

# %%
propLabel = []

for i in tqdm(range(len(propList))):
    query_string = """
    SELECT DISTINCT ?propLabel {
      VALUES ?p {wdt:""" + propList[i] + """}
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } 
      # ?prop wikibase:directClaim ?p .
    }
    """

    wikidata.setQuery(query_string)
    wikidata.setReturnFormat(JSON)
    results_prop = wikidata.query().convert()
    for results in results_prop["results"]["bindings"]:
#         print('%s: %s' % (results["country"]["value"], results["propLabel"]["value"]))
        propLabel.append(results["propLabel"]["value"])
#     print('---------------------------')
# Out:
# 100%|██████████| 53/53 [00:26<00:00,  1.97it/s]

# %%
df.columns = propLabel
df
# Out:
#     taxon rank  described by source  IUCN conservation status  GRIN URL  \
# 0         True                False                      True     False
# 1         True                False                     False     False
# 2         True                False                      True     False
# 3         True                False                      True     False
# 4         True                False                     False     False
# 5         True                False                     False      True
# 6         True                False                     False     False
# 7         True                False                     False     False
# 8         True                False                     False     False
# 9         True                 True                     False     False
# 10        True                False                     False     False
# 11        True                False                     False     False
# 12        True                False                     False     False
# 13        True                False                     False     False
# 14        True                False                     False     False
# 15        True                False                     False     False
# 16        True                False                     False     False
# 17        True                False                     False     False
#
#     has quality  parent taxon  image  taxon range map image  \
# 0         False          True   True                   True
# 1         False          True   True                  False
# 2         False          True   True                  False
# 3         False          True   True                  False
# 4         False          True   True                  False
# 5         False          True   True                  False
# 6          True          True   True                  False
# 7         False          True   True                  False
# 8         False          True   True                  False
# 9         False          True   True                  False
# 10        False          True   True                   True
# 11        False          True   True                   True
# 12        False          True   True                   True
# 13        False          True   True                   True
# 14        False          True   True                   True
# 15        False          True  False                   True
# 16        False          True   True                   True
# 17        False          True   True                  False
#
#     taxon common name  different from  ...  studied by  subclass of  habitat  \
# 0                True           False  ...       False         True    False
# 1               False           False  ...        True         True    False
# 2                True           False  ...       False         True    False
# 3                True           False  ...       False        False    False
# 4               False            True  ...       False        False     True
# 5                True           False  ...       False        False    False
# 6                True           False  ...       False        False    False
# 7                True           False  ...       False        False    False
# 8               False           False  ...       False        False    False
# 9               False           False  ...       False        False    False
# 10               True           False  ...       False        False    False
# 11               True           False  ...       False        False    False
# 12               True           False  ...       False        False    False
# 13              False           False  ...       False        False    False
# 14              False           False  ...       False        False    False
# 15              False           False  ...       False        False    False
# 16              False           False  ...       False        False    False
# 17              False           False  ...       False        False    False
#
#     instance of  means of locomotion  part of  taxonomic type  \
# 0          True                False    False           False
# 1          True                 True    False           False
# 2          True                False    False           False
# 3          True                False    False           False
# 4          True                False     True           False
# 5          True                False    False            True
# 6          True                False    False           False
# 7          True                False    False            True
# 8          True                False    False           False
# 9          True                False    False           False
# 10         True                False    False           False
# 11         True                False    False           False
# 12         True                False    False           False
# 13         True                False    False           False
# 14         True                False    False           False
# 15         True                False    False           False
# 16         True                False    False           False
# 17         True                False    False           False
#
#     on focus list of Wikimedia project  Wikimedia outline  \
# 0                                False              False
# 1                                 True               True
# 2                                False              False
# 3                                False              False
# 4                                False              False
# 5                                False              False
# 6                                False              False
# 7                                False              False
# 8                                False              False
# 9                                False              False
# 10                               False              False
# 11                               False              False
# 12                               False              False
# 13                               False              False
# 14                               False              False
# 15                               False              False
# 16                               False              False
# 17                               False              False
#
#     topic's main category
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# 5                    True
# 6                    True
# 7                    True
# 8                    True
# 9                    True
# 10                   True
# 11                   True
# 12                   True
# 13                   True
# 14                   True
# 15                   True
# 16                  False
# 17                  False
#
# [18 rows x 53 columns]

# %%
from mlxtend.frequent_patterns import association_rules, fpmax, fpgrowth

# %%
frequent_itemsets = fpgrowth(df, min_support=0.5, use_colnames=True)
frequent_itemsets
# Out:
#        support                                           itemsets
# 0     1.000000                                      (instance of)
# 1     1.000000                                     (parent taxon)
# 2     1.000000                                      (instance of)
# 3     1.000000                                       (taxon name)
# 4     1.000000                                     (parent taxon)
# ...        ...                                                ...
# 2554  0.722222  (taxon rank, parent taxon, image, instance of,...
# 2555  0.722222  (taxon rank, parent taxon, image, instance of,...
# 2556  0.722222  (taxon rank, parent taxon, image, instance of,...
# 2557  0.722222  (taxon rank, parent taxon, image, instance of,...
# 2558  0.722222  (taxon rank, parent taxon, image, instance of,...
#
# [2559 rows x 2 columns]

# %%
res = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
res
# Out:
#                               antecedents  \
# 0                          (parent taxon)
# 1                           (instance of)
# 2                           (instance of)
# 3                            (taxon name)
# 4                          (parent taxon)
# ...                                   ...
# 2535  (taxon name, topic's main category)
# 2536                         (taxon rank)
# 2537                   (Commons category)
# 2538                              (image)
# 2539              (topic's main category)
#
#                                             consequents  antecedent support  \
# 0                                         (instance of)            1.000000
# 1                                        (parent taxon)            1.000000
# 2                                          (taxon name)            1.000000
# 3                                         (instance of)            1.000000
# 4                                          (taxon name)            1.000000
# ...                                                 ...                 ...
# 2535  (taxon rank, Commons category, parent taxon, i...            0.777778
# 2536  (Commons category, parent taxon, image, instan...            0.944444
# 2537  (taxon rank, parent taxon, image, instance of,...            0.777778
# 2538  (taxon rank, Commons category, parent taxon, i...            0.944444
# 2539  (taxon rank, Commons category, parent taxon, i...            0.777778
#
#       consequent support   support  confidence      lift  leverage  conviction
# 0               1.000000  1.000000    1.000000  1.000000  0.000000         inf
# 1               1.000000  1.000000    1.000000  1.000000  0.000000         inf
# 2               1.000000  1.000000    1.000000  1.000000  0.000000         inf
# 3               1.000000  1.000000    1.000000  1.000000  0.000000         inf
# 4               1.000000  1.000000    1.000000  1.000000  0.000000         inf
# ...                  ...       ...         ...       ...       ...         ...
# 2535            0.666667  0.666667    0.857143  1.285714  0.148148    2.333333
# 2536            0.666667  0.666667    0.705882  1.058824  0.037037    1.133333
# 2537            0.722222  0.666667    0.857143  1.186813  0.104938    1.944444
# 2538            0.722222  0.666667    0.705882  0.977376 -0.015432    0.944444
# 2539            0.666667  0.666667    0.857143  1.285714  0.148148    2.333333
#
# [2540 rows x 9 columns]
