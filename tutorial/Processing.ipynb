# %%
import numpy as np
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
from apyori import apriori
from mlxtend.preprocessing import TransactionEncoder
from tqdm import tqdm

# %%
queryString = "SELECT * WHERE { ?s ?p ?o. }"
sparql = SPARQLWrapper("http://localhost:3030/memory/sparql")
sparql.setQuery(queryString)

try :
   ret = sparql.query()
   # ret is a stream with the results in XML, see <http://www.w3.org/TR/rdf-sparql-XMLres/>
except :
   pass

# %%
sparql.setQuery("""
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT ?country (COUNT(?prop) AS ?total) {
  
  SELECT DISTINCT ?country ?prop
    WHERE {
    # ?country wdt:P31 wd:Q3624078 .
    # ?country ?prop ?value .
} 

} GROUP BY ?country
ORDER BY DESC(?total) 
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
res = []
for results in results["results"]["bindings"]:
    print('%s: %s' % (results["country"]["value"], results["total"]["value"]))
    entity = str(results["country"]["value"]).split('/')
    res.append(entity[-1])
print('---------------------------')
# Out:
# http://www.wikidata.org/entity/Q142: 126
# http://www.wikidata.org/entity/Q30: 125
# http://www.wikidata.org/entity/Q801: 124
# http://www.wikidata.org/entity/Q183: 121
# http://www.wikidata.org/entity/Q213: 119
# http://www.wikidata.org/entity/Q408: 118
# http://www.wikidata.org/entity/Q16: 116
# http://www.wikidata.org/entity/Q159: 115
# http://www.wikidata.org/entity/Q668: 115
# http://www.wikidata.org/entity/Q17: 113
# http://www.wikidata.org/entity/Q29: 113
# http://www.wikidata.org/entity/Q31: 113
# http://www.wikidata.org/entity/Q33: 113
# http://www.wikidata.org/entity/Q851: 112
# http://www.wikidata.org/entity/Q155: 111
# http://www.wikidata.org/entity/Q884: 109
# http://www.wikidata.org/entity/Q145: 108
# http://www.wikidata.org/entity/Q212: 108
# http://www.wikidata.org/entity/Q41: 108
# http://www.wikidata.org/entity/Q148: 106
# http://www.wikidata.org/entity/Q20: 106
# http://www.wikidata.org/entity/Q34: 106
# http://www.wikidata.org/entity/Q43: 106
# http://www.wikidata.org/entity/Q252: 105
# http://www.wikidata.org/entity/Q36: 105
# http://www.wikidata.org/entity/Q38: 105
# http://www.wikidata.org/entity/Q414: 105
# http://www.wikidata.org/entity/Q184: 104
# http://www.wikidata.org/entity/Q28: 104
# http://www.wikidata.org/entity/Q27: 103
# http://www.wikidata.org/entity/Q794: 103
# http://www.wikidata.org/entity/Q948: 103
# http://www.wikidata.org/entity/Q258: 102
# http://www.wikidata.org/entity/Q39: 102
# http://www.wikidata.org/entity/Q664: 102
# http://www.wikidata.org/entity/Q833: 102
# http://www.wikidata.org/entity/Q96: 102
# http://www.wikidata.org/entity/Q189: 101
# http://www.wikidata.org/entity/Q40: 101
# http://www.wikidata.org/entity/Q45: 101
# http://www.wikidata.org/entity/Q1028: 100
# http://www.wikidata.org/entity/Q215: 100
# http://www.wikidata.org/entity/Q863: 81
# http://www.wikidata.org/entity/Q945: 81
# http://www.wikidata.org/entity/Q1037: 80
# http://www.wikidata.org/entity/Q574: 80
# http://www.wikidata.org/entity/Q760: 80
# http://www.wikidata.org/entity/Q826: 80
# http://www.wikidata.org/entity/Q971: 80
# http://www.wikidata.org/entity/Q678: 79
# http://www.wikidata.org/entity/Q769: 79
# http://www.wikidata.org/entity/Q970: 79
# http://www.wikidata.org/entity/Q685: 78
# http://www.wikidata.org/entity/Q709: 78
# http://www.wikidata.org/entity/Q1039: 77
# http://www.wikidata.org/entity/Q686: 77
# http://www.wikidata.org/entity/Q710: 77
# http://www.wikidata.org/entity/Q757: 77
# http://www.wikidata.org/entity/Q763: 77
# http://www.wikidata.org/entity/Q781: 75
# http://www.wikidata.org/entity/Q958: 74
# http://www.wikidata.org/entity/Q697: 73
# http://www.wikidata.org/entity/Q756617: 73
# http://www.wikidata.org/entity/Q754: 72
# http://www.wikidata.org/entity/Q672: 69
# http://www.wikidata.org/entity/Q29999: 56
# http://www.wikidata.org/entity/Q106234285: 6
# ---------------------------

# %%
db = []

for i in range(len(res)):
    query_string = """
    PREFIX wd: <http://www.wikidata.org/entity/>
    SELECT DISTINCT ?country ?prop {
    VALUES ?country {wd:""" + res[i] + """}
    # ?country ?prop ?value .
    }
    """

    sparql.setQuery(query_string)
    sparql.setReturnFormat(JSON)
    results_entity = sparql.query().convert()
    propLabel = []
    for results in results_entity["results"]["bindings"]:
#         print('%s: %s' % (results["country"]["value"], results["propLabel"]["value"]))
        propLabel.append(results["prop"]["value"])
#     print('---------------------------')
    db.append(propLabel)

# %%
te = TransactionEncoder()
te_ary = te.fit(db).transform(db)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      http://www.wikidata.org/prop/direct/P10  \
# 0                                      False
# 1                                      False
# 2                                       True
# 3                                      False
# 4                                      False
# ..                                       ...
# 192                                    False
# 193                                    False
# 194                                    False
# 195                                    False
# 196                                    False
#
#      http://www.wikidata.org/prop/direct/P1001  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P103  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 192                                     False
# 193                                     False
# 194                                     False
# 195                                     False
# 196                                     False
#
#      http://www.wikidata.org/prop/direct/P1081  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# ..                                         ...
# 192                                      False
# 193                                       True
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P1082  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# ..                                         ...
# 192                                       True
# 193                                       True
# 194                                       True
# 195                                       True
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P112  \
# 0                                       False
# 1                                       False
# 2                                        True
# 3                                       False
# 4                                       False
# ..                                        ...
# 192                                     False
# 193                                     False
# 194                                     False
# 195                                     False
# 196                                     False
#
#      http://www.wikidata.org/prop/direct/P1120  \
# 0                                         True
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P1125  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                        False
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P1151  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                         True
# ..                                         ...
# 192                                       True
# 193                                       True
# 194                                       True
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P1174  ...  \
# 0                                        False  ...
# 1                                        False  ...
# 2                                        False  ...
# 3                                        False  ...
# 4                                        False  ...
# ..                                         ...  ...
# 192                                      False  ...
# 193                                      False  ...
# 194                                      False  ...
# 195                                      False  ...
# 196                                      False  ...
#
#      http://www.wikidata.org/prop/direct/P9318  \
# 0                                        False
# 1                                         True
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P9322  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P9346  \
# 0                                         True
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P9348  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P9349  \
# 0                                         True
# 1                                         True
# 2                                         True
# 3                                         True
# 4                                        False
# ..                                         ...
# 192                                      False
# 193                                      False
# 194                                      False
# 195                                      False
# 196                                      False
#
#      http://www.wikidata.org/prop/direct/P935  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ..                                        ...
# 192                                     False
# 193                                      True
# 194                                      True
# 195                                     False
# 196                                     False
#
#      http://www.wikidata.org/prop/direct/P94  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
# ..                                       ...
# 192                                     True
# 193                                     True
# 194                                     True
# 195                                     True
# 196                                    False
#
#      http://www.wikidata.org/prop/direct/P948  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ..                                        ...
# 192                                     False
# 193                                      True
# 194                                      True
# 195                                     False
# 196                                     False
#
#      http://www.wikidata.org/prop/direct/P973  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 192                                     False
# 193                                     False
# 194                                     False
# 195                                     False
# 196                                     False
#
#      http://www.wikidata.org/prop/direct/P989
# 0                                        True
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 192                                      True
# 193                                     False
# 194                                     False
# 195                                      True
# 196                                     False
#
# [197 rows x 242 columns]

# %%
wikidata = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
propList = df.columns.tolist()
for i in range(len(propList)):
    propList[i] = propList[i].split('/')[-1]

# %%
propLabel = []

for i in tqdm(range(len(propList))):
    query_string = """
    SELECT DISTINCT ?propLabel {
      VALUES ?p {wdt:""" + propList[i] + """}
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } 
      # ?prop wikibase:directClaim ?p .
    }
    """

    wikidata.setQuery(query_string)
    wikidata.setReturnFormat(JSON)
    results_prop = wikidata.query().convert()
    for results in results_prop["results"]["bindings"]:
#         print('%s: %s' % (results["country"]["value"], results["propLabel"]["value"]))
        propLabel.append(results["propLabel"]["value"])
#     print('---------------------------')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 242/242 [05:03<00:00,  1.25s/it]

# %%
df.columns = propLabel

# %%
df
# Out:
#      video  applies to jurisdiction  native language  Human Development Index  \
# 0    False                    False            False                     True
# 1    False                    False            False                     True
# 2     True                    False            False                     True
# 3    False                    False            False                     True
# 4    False                    False            False                     True
# ..     ...                      ...              ...                      ...
# 192  False                    False            False                    False
# 193  False                    False            False                     True
# 194  False                    False            False                    False
# 195  False                    False            False                    False
# 196  False                    False            False                    False
#
#      population  founded by  number of deaths  Gini coefficient  \
# 0          True       False              True              True
# 1          True       False             False              True
# 2          True        True             False              True
# 3          True       False             False             False
# 4          True       False             False             False
# ..          ...         ...               ...               ...
# 192        True       False             False             False
# 193        True       False             False             False
# 194        True       False             False             False
# 195        True       False             False             False
# 196       False       False             False             False
#
#      topic's main Wikimedia portal  visitors per year  ...  Ávvir topic ID  \
# 0                             True              False  ...           False
# 1                             True              False  ...            True
# 2                             True              False  ...           False
# 3                             True              False  ...           False
# 4                             True              False  ...           False
# ..                             ...                ...  ...             ...
# 192                           True              False  ...           False
# 193                           True              False  ...           False
# 194                           True              False  ...           False
# 195                          False              False  ...           False
# 196                          False              False  ...           False
#
#      SVKKL authority ID  France24 topic ID (French)  \
# 0                 False                        True
# 1                 False                       False
# 2                 False                       False
# 3                 False                       False
# 4                 False                       False
# ..                  ...                         ...
# 192               False                       False
# 193               False                       False
# 194               False                       False
# 195               False                       False
# 196               False                       False
#
#      France24 topic ID (Spanish)  France24 topic ID (Arabic)  Commons gallery  \
# 0                          False                        True             True
# 1                          False                        True             True
# 2                          False                        True             True
# 3                          False                        True             True
# 4                          False                       False             True
# ..                           ...                         ...              ...
# 192                        False                       False            False
# 193                        False                       False             True
# 194                        False                       False             True
# 195                        False                       False            False
# 196                        False                       False            False
#
#      coat of arms image  page banner  described at URL  spoken text audio
# 0                  True         True             False               True
# 1                  True         True             False               True
# 2                  True         True             False              False
# 3                  True         True             False              False
# 4                  True         True             False              False
# ..                  ...          ...               ...                ...
# 192                True        False             False               True
# 193                True         True             False              False
# 194                True         True             False              False
# 195                True        False             False               True
# 196               False        False             False              False
#
# [197 rows x 242 columns]
