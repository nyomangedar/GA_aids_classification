# %%
import numpy as np
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
from apyori import apriori
from mlxtend.preprocessing import TransactionEncoder
from tqdm import tqdm

# %%
queryString = "SELECT * WHERE { ?s ?p ?o. }"
sparql = SPARQLWrapper("http://localhost:3030/Physical_Object")
sparql.setQuery(queryString)

try :
   ret = sparql.query()
   # ret is a stream with the results in XML, see <http://www.w3.org/TR/rdf-sparql-XMLres/>
except :
   pass

# %%
sparql.setQuery("""
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
SELECT ?country (COUNT(?prop) AS ?total) {
  
  SELECT DISTINCT ?country ?prop
    WHERE {
    # ?country wdt:P31 wd:Q223557 .
    # ?country ?prop ?value .
} 

} GROUP BY ?country
ORDER BY DESC(?total)
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
res = []
for results in results["results"]["bindings"]:
    print('%s: %s' % (results["country"]["value"], results["total"]["value"]))
    entity = str(results["country"]["value"]).split('/')
    res.append(entity[-1])
print('---------------------------')
# Out:
# http://www.wikidata.org/entity/Q86870962: 27
# http://www.wikidata.org/entity/Q98833586: 26
# http://www.wikidata.org/entity/Q29321377: 24
# http://www.wikidata.org/entity/Q20877089: 23
# http://www.wikidata.org/entity/Q29318871: 18
# http://www.wikidata.org/entity/Q96573964: 16
# http://www.wikidata.org/entity/Q96587104: 16
# http://www.wikidata.org/entity/Q722218: 14
# http://www.wikidata.org/entity/Q81973728: 14
# http://www.wikidata.org/entity/Q394352: 13
# http://www.wikidata.org/entity/Q60740239: 13
# http://www.wikidata.org/entity/Q63554971: 13
# http://www.wikidata.org/entity/Q60024227: 12
# http://www.wikidata.org/entity/Q60740792: 12
# http://www.wikidata.org/entity/Q60751750: 12
# http://www.wikidata.org/entity/Q60759687: 12
# http://www.wikidata.org/entity/Q60763364: 12
# http://www.wikidata.org/entity/Q60777976: 12
# http://www.wikidata.org/entity/Q65944235: 12
# http://www.wikidata.org/entity/Q65944236: 12
# http://www.wikidata.org/entity/Q65944238: 12
# http://www.wikidata.org/entity/Q65944239: 12
# http://www.wikidata.org/entity/Q65944241: 12
# http://www.wikidata.org/entity/Q65944242: 12
# http://www.wikidata.org/entity/Q65944243: 12
# http://www.wikidata.org/entity/Q65944244: 12
# http://www.wikidata.org/entity/Q65944246: 12
# http://www.wikidata.org/entity/Q65944248: 12
# http://www.wikidata.org/entity/Q65944250: 12
# http://www.wikidata.org/entity/Q65944255: 12
# http://www.wikidata.org/entity/Q65944262: 12
# http://www.wikidata.org/entity/Q65944264: 12
# http://www.wikidata.org/entity/Q65944265: 12
# http://www.wikidata.org/entity/Q65944270: 12
# http://www.wikidata.org/entity/Q65944273: 12
# http://www.wikidata.org/entity/Q65944274: 12
# http://www.wikidata.org/entity/Q65944276: 12
# http://www.wikidata.org/entity/Q65944277: 12
# http://www.wikidata.org/entity/Q65944285: 12
# http://www.wikidata.org/entity/Q65944290: 12
# http://www.wikidata.org/entity/Q65944295: 12
# http://www.wikidata.org/entity/Q65944296: 12
# http://www.wikidata.org/entity/Q65944297: 12
# http://www.wikidata.org/entity/Q65944298: 12
# http://www.wikidata.org/entity/Q65944299: 12
# http://www.wikidata.org/entity/Q65944405: 12
# http://www.wikidata.org/entity/Q82628105: 12
# http://www.wikidata.org/entity/Q65944237: 10
# http://www.wikidata.org/entity/Q65944245: 10
# http://www.wikidata.org/entity/Q65944251: 10
# http://www.wikidata.org/entity/Q65944252: 10
# http://www.wikidata.org/entity/Q65944253: 10
# http://www.wikidata.org/entity/Q65944254: 10
# http://www.wikidata.org/entity/Q65944258: 10
# http://www.wikidata.org/entity/Q65944260: 10
# http://www.wikidata.org/entity/Q65944261: 10
# http://www.wikidata.org/entity/Q65944263: 10
# http://www.wikidata.org/entity/Q65944266: 10
# http://www.wikidata.org/entity/Q65944267: 10
# http://www.wikidata.org/entity/Q65944271: 10
# http://www.wikidata.org/entity/Q65944272: 10
# http://www.wikidata.org/entity/Q65944278: 10
# http://www.wikidata.org/entity/Q65944279: 10
# http://www.wikidata.org/entity/Q65944281: 10
# http://www.wikidata.org/entity/Q65944282: 10
# http://www.wikidata.org/entity/Q65944283: 10
# http://www.wikidata.org/entity/Q65944284: 10
# http://www.wikidata.org/entity/Q65944287: 10
# http://www.wikidata.org/entity/Q65944288: 10
# http://www.wikidata.org/entity/Q65944289: 10
# http://www.wikidata.org/entity/Q65944292: 10
# http://www.wikidata.org/entity/Q65944294: 10
# http://www.wikidata.org/entity/Q79473720: 10
# http://www.wikidata.org/entity/Q79473936: 10
# http://www.wikidata.org/entity/Q79474094: 10
# http://www.wikidata.org/entity/Q79474113: 10
# http://www.wikidata.org/entity/Q92413146: 10
# http://www.wikidata.org/entity/Q106311380: 9
# http://www.wikidata.org/entity/Q505531: 9
# http://www.wikidata.org/entity/Q693464: 9
# http://www.wikidata.org/entity/Q79474117: 9
# http://www.wikidata.org/entity/Q860571: 9
# http://www.wikidata.org/entity/Q11394841: 8
# http://www.wikidata.org/entity/Q34724893: 8
# http://www.wikidata.org/entity/Q4279993: 8
# http://www.wikidata.org/entity/Q456627: 8
# http://www.wikidata.org/entity/Q79474121: 8
# http://www.wikidata.org/entity/Q92407553: 8
# http://www.wikidata.org/entity/Q101209947: 7
# http://www.wikidata.org/entity/Q106311472: 7
# http://www.wikidata.org/entity/Q45100013: 7
# http://www.wikidata.org/entity/Q104127240: 6
# http://www.wikidata.org/entity/Q10895005: 6
# http://www.wikidata.org/entity/Q44742777: 6
# http://www.wikidata.org/entity/Q6332347: 6
# http://www.wikidata.org/entity/Q9392077: 6
# http://www.wikidata.org/entity/Q24251437: 5
# http://www.wikidata.org/entity/Q2851422: 5
# http://www.wikidata.org/entity/Q3346827: 5
# http://www.wikidata.org/entity/Q105986333: 4
# http://www.wikidata.org/entity/Q1622547: 4
# http://www.wikidata.org/entity/Q184747: 4
# http://www.wikidata.org/entity/Q4268202: 3
# http://www.wikidata.org/entity/Q23052894: 2
# http://www.wikidata.org/entity/Q765382: 2
# ---------------------------

# %%
db = []

for i in range(len(res)):
    query_string = """
    PREFIX wd: <http://www.wikidata.org/entity/>
    SELECT DISTINCT ?country ?prop {
    VALUES ?country {wd:""" + res[i] + """}
    # ?country ?prop ?value .
    }
    """

    sparql.setQuery(query_string)
    sparql.setReturnFormat(JSON)
    results_entity = sparql.query().convert()
    propLabel = []
    for results in results_entity["results"]["bindings"]:
#         print('%s: %s' % (results["country"]["value"], results["propLabel"]["value"]))
        propLabel.append(results["prop"]["value"])
#     print('---------------------------')
    db.append(propLabel)

# %%
te = TransactionEncoder()
te_ary = te.fit(db).transform(db)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      http://www.wikidata.org/prop/P1071  http://www.wikidata.org/prop/P1114  \
# 0                                 False                               False
# 1                                 False                               False
# 2                                 False                               False
# 3                                 False                                True
# 4                                 False                               False
# ..                                  ...                                 ...
# 100                               False                               False
# 101                               False                               False
# 102                               False                               False
# 103                               False                               False
# 104                               False                               False
#
#      http://www.wikidata.org/prop/P1269  http://www.wikidata.org/prop/P127  \
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
# 3                                 False                              False
# 4                                 False                              False
# ..                                  ...                                ...
# 100                               False                              False
# 101                               False                              False
# 102                               False                              False
# 103                               False                              False
# 104                               False                              False
#
#      http://www.wikidata.org/prop/P131  http://www.wikidata.org/prop/P1343  \
# 0                                 True                               False
# 1                                 True                               False
# 2                                 True                               False
# 3                                False                               False
# 4                                 True                               False
# ..                                 ...                                 ...
# 100                              False                               False
# 101                              False                               False
# 102                              False                               False
# 103                              False                               False
# 104                              False                               False
#
#      http://www.wikidata.org/prop/P135  http://www.wikidata.org/prop/P136  \
# 0                                False                               True
# 1                                 True                               True
# 2                                False                               True
# 3                                False                              False
# 4                                False                               True
# ..                                 ...                                ...
# 100                              False                              False
# 101                              False                              False
# 102                              False                              False
# 103                              False                              False
# 104                              False                              False
#
#      http://www.wikidata.org/prop/P1402  http://www.wikidata.org/prop/P1424  \
# 0                                 False                               False
# 1                                 False                               False
# 2                                 False                               False
# 3                                 False                               False
# 4                                 False                               False
# ..                                  ...                                 ...
# 100                               False                               False
# 101                               False                               False
# 102                               False                               False
# 103                               False                               False
# 104                               False                               False
#
#      ...  http://www.wikidata.org/prop/direct/P5008  \
# 0    ...                                      False
# 1    ...                                      False
# 2    ...                                      False
# 3    ...                                      False
# 4    ...                                      False
# ..   ...                                        ...
# 100  ...                                      False
# 101  ...                                      False
# 102  ...                                      False
# 103  ...                                      False
# 104  ...                                      False
#
#      http://www.wikidata.org/prop/direct/P527  \
# 0                                        True
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                        True
# ..                                        ...
# 100                                     False
# 101                                     False
# 102                                     False
# 103                                     False
# 104                                     False
#
#      http://www.wikidata.org/prop/direct/P547  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                        True
# 4                                       False
# ..                                        ...
# 100                                     False
# 101                                     False
# 102                                     False
# 103                                     False
# 104                                     False
#
#      http://www.wikidata.org/prop/direct/P61  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 100                                    False
# 101                                    False
# 102                                    False
# 103                                    False
# 104                                    False
#
#      http://www.wikidata.org/prop/direct/P6216  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 100                                      False
# 101                                      False
# 102                                      False
# 103                                      False
# 104                                      False
#
#      http://www.wikidata.org/prop/direct/P65  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 100                                    False
# 101                                    False
# 102                                    False
# 103                                    False
# 104                                    False
#
#      http://www.wikidata.org/prop/direct/P737  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 100                                     False
# 101                                     False
# 102                                     False
# 103                                     False
# 104                                     False
#
#      http://www.wikidata.org/prop/direct/P793  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 100                                     False
# 101                                     False
# 102                                     False
# 103                                     False
# 104                                     False
#
#      http://www.wikidata.org/prop/direct/P910  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 100                                     False
# 101                                     False
# 102                                     False
# 103                                     False
# 104                                     False
#
#      http://www.wikidata.org/prop/direct/P921
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                       False
# 4                                       False
# ..                                        ...
# 100                                     False
# 101                                     False
# 102                                     False
# 103                                     False
# 104                                     False
#
# [105 rows x 107 columns]

# %%
wikidata = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
propList = df.columns.tolist()
for i in range(len(propList)):
    propList[i] = propList[i].split('/')[-1]

# %%
propLabel = []

for i in tqdm(range(len(propList))):
    query_string = """
    SELECT DISTINCT ?propLabel {
      VALUES ?p {wdt:""" + propList[i] + """}
      SERVICE wikibase:label { bd:serviceParam wikibase:language "en". } 
      # ?prop wikibase:directClaim ?p .
    }
    """

    wikidata.setQuery(query_string)
    wikidata.setReturnFormat(JSON)
    results_prop = wikidata.query().convert()
    for results in results_prop["results"]["bindings"]:
#         print('%s: %s' % (results["country"]["value"], results["propLabel"]["value"]))
        propLabel.append(results["propLabel"]["value"])
#     print('---------------------------')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 107/107 [00:56<00:00,  1.90it/s]

# %%
df.columns = propLabel

# %%
df
# Out:
#      location of creation  quantity  facet of  owned by  \
# 0                   False     False     False     False
# 1                   False     False     False     False
# 2                   False     False     False     False
# 3                   False      True     False     False
# 4                   False     False     False     False
# ..                    ...       ...       ...       ...
# 100                 False     False     False     False
# 101                 False     False     False     False
# 102                 False     False     False     False
# 103                 False     False     False     False
# 104                 False     False     False     False
#
#      located in the administrative territorial entity  described by source  \
# 0                                                True                False
# 1                                                True                False
# 2                                                True                False
# 3                                               False                False
# 4                                                True                False
# ..                                                ...                  ...
# 100                                             False                False
# 101                                             False                False
# 102                                             False                False
# 103                                             False                False
# 104                                             False                False
#
#      movement  genre  Foundational Model of Anatomy ID  topic's main template  \
# 0       False   True                             False                  False
# 1        True   True                             False                  False
# 2       False   True                             False                  False
# 3       False  False                             False                  False
# 4       False   True                             False                  False
# ..        ...    ...                               ...                    ...
# 100     False  False                             False                  False
# 101     False  False                             False                  False
# 102     False  False                             False                  False
# 103     False  False                             False                  False
# 104     False  False                             False                  False
#
#      ...  on focus list of Wikimedia project  has part  commemorates  \
# 0    ...                               False      True         False
# 1    ...                               False     False         False
# 2    ...                               False     False         False
# 3    ...                               False     False          True
# 4    ...                               False      True         False
# ..   ...                                 ...       ...           ...
# 100  ...                               False     False         False
# 101  ...                               False     False         False
# 102  ...                               False     False         False
# 103  ...                               False     False         False
# 104  ...                               False     False         False
#
#      discoverer or inventor  copyright status  site of astronomical discovery  \
# 0                     False             False                           False
# 1                     False             False                           False
# 2                     False             False                           False
# 3                     False             False                           False
# 4                     False             False                           False
# ..                      ...               ...                             ...
# 100                   False             False                           False
# 101                   False             False                           False
# 102                   False             False                           False
# 103                   False             False                           False
# 104                   False             False                           False
#
#      influenced by  significant event  topic's main category  main subject
# 0            False              False                  False          True
# 1             True              False                  False          True
# 2            False              False                  False          True
# 3            False              False                  False         False
# 4            False              False                  False         False
# ..             ...                ...                    ...           ...
# 100          False              False                  False         False
# 101          False              False                  False         False
# 102          False              False                  False         False
# 103          False              False                  False         False
# 104          False              False                  False         False
#
# [105 rows x 107 columns]

# %%
from mlxtend.frequent_patterns import association_rules, fpmax, fpgrowth

# %%
frequent_itemsets = fpgrowth(df, min_support=0.5, use_colnames=True)

# %%
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    1.000000                                      (instance of)
# 1    1.000000                                      (instance of)
# 2    0.600000                               (made from material)
# 3    0.600000                               (made from material)
# 4    0.695238                                 (inventory number)
# ..        ...                                                ...
# 262  0.504762  (instance of, owned by, described at URL, made...
# 263  0.504762  (instance of, owned by, inventory number, made...
# 264  0.504762  (instance of, owned by, inventory number, made...
# 265  0.504762  (instance of, owned by, inventory number, made...
# 266  0.504762  (instance of, owned by, inventory number, made...
#
# [267 rows x 2 columns]

# %%
res = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
res
# Out:
#                                 antecedents  \
# 0                      (made from material)
# 1                      (made from material)
# 2                        (inventory number)
# 3                      (made from material)
# 4                        (described at URL)
# ..                                      ...
# 161  (made from material, described at URL)
# 162                              (owned by)
# 163                      (inventory number)
# 164                    (made from material)
# 165                      (described at URL)
#
#                                            consequents  antecedent support  \
# 0                                        (instance of)            0.600000
# 1                                   (inventory number)            0.600000
# 2                                 (made from material)            0.695238
# 3                                   (described at URL)            0.600000
# 4                                 (made from material)            0.657143
# ..                                                 ...                 ...
# 161          (instance of, owned by, inventory number)            0.523810
# 162  (instance of, inventory number, described at U...            0.523810
# 163  (instance of, owned by, described at URL, made...            0.695238
# 164  (instance of, owned by, inventory number, desc...            0.600000
# 165  (instance of, owned by, inventory number, made...            0.657143
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              1.000000  0.600000    1.000000  1.000000  0.000000         inf
# 1              0.695238  0.523810    0.873016  1.255708  0.106667    2.400000
# 2              0.600000  0.523810    0.753425  1.255708  0.106667    1.622222
# 3              0.657143  0.523810    0.873016  1.328502  0.129524    2.700000
# 4              0.600000  0.523810    0.797101  1.328502  0.129524    1.971429
# ..                  ...       ...         ...       ...       ...         ...
# 161            0.514286  0.504762    0.963636  1.873737  0.235374   13.357143
# 162            0.514286  0.504762    0.963636  1.873737  0.235374   13.357143
# 163            0.504762  0.504762    0.726027  1.438356  0.153832    1.807619
# 164            0.504762  0.504762    0.841270  1.666667  0.201905    3.120000
# 165            0.504762  0.504762    0.768116  1.521739  0.173061    2.135714
#
# [166 rows x 9 columns]
