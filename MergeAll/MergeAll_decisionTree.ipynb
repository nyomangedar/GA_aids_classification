# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import plot_confusion_matrix
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'D:\UniversityStuff\FourthTerm\AIDS\GA\MergeAll\merge_property.csv')
data
# Out:
#        video  applies to jurisdiction  including  web feed URL  donated by  \
# 0      False                    False      False         False       False
# 1      False                    False      False         False       False
# 2      False                    False      False         False       False
# 3      False                    False      False         False       False
# 4      False                    False      False         False       False
# ...      ...                      ...        ...           ...         ...
# 13657  False                    False      False         False       False
# 13658  False                    False      False         False       False
# 13659  False                    False      False         False       False
# 13660  False                    False      False         False       False
# 13661  False                    False      False         False       False
#
#        native language  product or material produced  occupation  \
# 0                False                         False       False
# 1                False                         False       False
# 2                False                         False       False
# 3                False                         False       False
# 4                False                         False       False
# ...                ...                           ...         ...
# 13657            False                         False       False
# 13658            False                         False       False
# 13659            False                         False       False
# 13660            False                         False       False
# 13661            False                         False       False
#
#        Human Development Index  population  ...  commemorates  \
# 0                         True        True  ...         False
# 1                         True        True  ...         False
# 2                        False        True  ...         False
# 3                        False        True  ...         False
# 4                        False        True  ...         False
# ...                        ...         ...  ...           ...
# 13657                    False       False  ...         False
# 13658                    False       False  ...         False
# 13659                    False       False  ...         False
# 13660                    False       False  ...         False
# 13661                    False       False  ...         False
#
#        copyright status  site of astronomical discovery  curator.1  depicts.1  \
# 0                 False                           False      False      False
# 1                 False                           False      False      False
# 2                 False                           False      False      False
# 3                 False                           False      False      False
# 4                 False                           False      False      False
# ...                 ...                             ...        ...        ...
# 13657             False                           False      False      False
# 13658             False                           False      False      False
# 13659             False                           False      False      False
# 13660             False                           False      False      False
# 13661             False                           False      False      False
#
#        contains.1  commemorates.1  copyright status.1  \
# 0           False           False               False
# 1           False           False               False
# 2           False           False               False
# 3           False           False               False
# 4           False           False               False
# ...           ...             ...                 ...
# 13657       False           False               False
# 13658       False           False               False
# 13659       False           False               False
# 13660       False           False               False
# 13661       False           False               False
#
#        site of astronomical discovery.1    Label
# 0                                 False     City
# 1                                 False     City
# 2                                 False     City
# 3                                 False     City
# 4                                 False     City
# ...                                 ...      ...
# 13657                             False  PhysObj
# 13658                             False  PhysObj
# 13659                             False  PhysObj
# 13660                             False  PhysObj
# 13661                             False  PhysObj
#
# [13662 rows x 837 columns]

# %%
feature = data.columns[0:-1]
featurename=[]
for i in range (len(feature)):
    featurename.append(feature[i])
x = data.iloc[:, 0:-1]
y = data.Label

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9448646011222249

# %%
#Confusion Matrix
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[ 816,   34,   17,    0,    0],
#        [ 113, 2557,    8,    0,    0],
#        [  31,    9,  470,    0,    2],
#        [   5,    2,    4,   24,    0],
#        [   0,    0,    1,    0,    6]], dtype=int64)

# %%
SVC(random_state=0)
plot_confusion_matrix(clf, x_test, y_test)  
plt.show()
